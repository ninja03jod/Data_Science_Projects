# %% [markdown]
# <a href="https://colab.research.google.com/github/ninja03jod/Data_Science_Projects/blob/main/_Marketing_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv("/content/Market.csv")
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df.shape
# Out:
# (112457, 8)

# %%
df.describe(include="all")
# Out:
#          Index       Date           Open           High            Low  \
# count   112457     112457  110253.000000  110252.000000  110251.000000
# unique      14      14731            NaN            NaN            NaN
# top       N225  11/3/2017            NaN            NaN            NaN
# freq     14500         14            NaN            NaN            NaN
# mean       NaN        NaN    7658.561932    7704.538416    7608.129749
# std        NaN        NaN    9011.455529    9066.605458    8954.536718
# min        NaN        NaN      54.869999      54.869999      54.869999
# 25%        NaN        NaN    1855.060059    1864.687470    1844.015015
# 50%        NaN        NaN    5194.399902    5226.750000    5154.299805
# 75%        NaN        NaN   10134.299810   10207.827635   10060.369630
# max        NaN        NaN   68775.062500   69403.750000   68516.992190
#
#                 Close      Adj Close        Volume
# count   110250.000000  110244.000000  1.102530e+05
# ...

# %%
df2.isna().sum()
# Out:
# Index           0
# Date            0
# Open         2204
# High         2205
# Low          2206
# Close        2207
# Adj Close    2213
# Volume       2204
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.shape
# Out:
# (110238, 8)

# %%
df2 = df.copy()

# %%
df2 = df2.dropna()
df2 = df2.drop_duplicates()

# %%
df2
# Out:
#        Index        Date     Open         High          Low        Close  \
# 0        NYA  12/31/1965  7658.56   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966  7658.56   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966  7658.56   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966  7658.56   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966  7658.56   532.070007   532.070007   532.070007
# ...      ...         ...      ...          ...          ...          ...
# 112452  N100   5/27/2021  7658.56  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  7658.56  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  7658.56  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  7658.56  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  7658.56  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# 0        528.690002          0.0
# ...

# %%
# represent the bar plot:
plt.bar(df["Date"],df["Adj Close"])
plt.xlabel("Dates")
plt.ylabel("Adj Close")

# %%
df3 = df2.tail(100)
df3
# Out:
#        Index       Date     Open         High          Low        Close  \
# 112357  N100  1/12/2021  7658.56  1127.520020  1119.510010  1122.560059
# 112358  N100  1/13/2021  7658.56  1126.079956  1119.540039  1123.609985
# 112359  N100  1/14/2021  7658.56  1134.280029  1127.500000  1133.199951
# 112360  N100  1/15/2021  7658.56  1129.719971  1114.010010  1121.800049
# 112361  N100  1/18/2021  7658.56  1123.500000  1117.989990  1122.540039
# ...      ...        ...      ...          ...          ...          ...
# 112452  N100  5/27/2021  7658.56  1251.910034  1241.119995  1247.069946
# 112453  N100  5/28/2021  7658.56  1259.209961  1249.030029  1256.599976
# 112454  N100  5/31/2021  7658.56  1258.880005  1248.140015  1248.930054
# 112455  N100   6/1/2021  7658.56  1265.660034  1254.609985  1258.579956
# 112456  N100   6/2/2021  7658.56  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# 112357  1122.560059  202431700.0
# 112358  1123.609985  237267700.0
# ...

# %%
plt.scatter(df3["Date"],df3["Adj Close"],marker="^",edgecolor="r",linewidths=2)
plt.xlabel("Dates")
plt.ylabel("Adj Close")
plt.grid()

# %%
plt.scatter(df3["Open"],df3["Adj Close"],marker="^",edgecolor="r",linewidths=2,s=10)
plt.xlabel("Open price")
plt.ylabel("Adj Close price")
plt.grid()
plt.show()

# %%
plt.scatter(df3["High"],df3["Adj Close"],marker="^",edgecolor="r",linewidths=2,s=10)
plt.xlabel("High")
plt.ylabel("Adj Close")
plt.grid()

# %%
plt.plot(df["High"],df["Adj Close"],"--k")

plt.scatter(df["High"],df["Adj Close"],s=10,marker="o",edgecolor="r",linewidths=2)
plt.xlabel("High Price")
plt.ylabel("Close Price")
plt.grid()
plt.show()

# %%
plt.scatter(df3["Low"],df3["Adj Close"],marker="^",edgecolor="r",linewidths=2)
plt.xlabel("Low")
plt.ylabel("Adj Close")
plt.grid()

# %%
plt.scatter(df3["Adj Close"],df3["Volume"],marker="^",edgecolor="r",linewidths=2)
plt.xlabel("Adj Close")
plt.ylabel("Volume")
plt.grid()

# %%
plt.scatter(df['Volume'],df['Adj Close'])
plt.xlabel('Volume')
plt.ylabel('Adj Close')
plt.title('Covariance='+str(df.cov()['Volume']['Adj Close']))
plt.show()
# Out:
# <ipython-input-51-09f6ad821f12>:4: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.title('Covariance='+str(df.cov()['Volume']['Adj Close']))

# %%
# plot line chart for Close price
plt.figure(figsize=(15,8))
plt.plot(df.index,df["Adj Close"],label="Market Price")
plt.legend()
plt.title('Market Price Over Time')
plt.xlabel('ravand harakat geymat ')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)  # Add grid lines
plt.show()
